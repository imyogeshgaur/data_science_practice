# %%
import pandas as pd
animals = ['Tigers','bears','Moose']
print(pd.Series(animals))
# Out:
# 0    Tigers
# 1     bears
# 2     Moose
# dtype: object

# %%
numbers=[1,2,3]
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
numbers=[1,2,3,None]
pd.Series(numbers)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# dtype: float64

# %%
import numpy as np  
np.nan == None
# Out:
# False

# %%
np.isnan(np.nan)
# Out:
# True

# %%
sports = { "Archery": "Bhutan",
          "Golf": "Scotland",
          "Sumo": "Japan",
          "Taykemondo" : "South Korea"}
s=pd.Series(sports)
s
# Out:
# Archery            Bhutan
# Golf             Scotland
# Sumo                Japan
# Taykemondo    South Korea
# dtype: object

# %%
s.index
# Out:
# Index(['Archery', 'Golf', 'Sumo', 'Taykemondo'], dtype='object')

# %%
a = pd.Series(['Tiger','Bear','Moose'],index=['India','Bhutan','Nepal'])
a
# Out:
# India     Tiger
# Bhutan     Bear
# Nepal     Moose
# dtype: object

# %%
b= pd.Series(['Tiger','Bear','Moose'],index=['India','Bhutan','Nepal'])
b
# Out:
# India     Tiger
# Bhutan     Bear
# Nepal     Moose
# dtype: object

# %%
df = pd.read_csv('ME.csv')
df
# Out:
#     S. NO.       REG. NO.       ROLL NO.        STUDENT NAME  \
# 0        1  REGKEC/268/19  1901610400001               AMAAN
# 1        2  REGKEC/253/19  1901610400002           ANMOL JHA
# 2        3  REGKEC/627/19  1901610400003          ARUN KUMAR
# 3        4  REGKEC/424/19  1901610400004        ARUNAV KUMAR
# 4        5  REGKEC/794/19  1901610400005       ASHOK CHAUHAN
# 5        6  REGKEC/183/19  1901610400006       DALJEET SINGH
# 6        7  REGKEC/674/19  1901610400007            DEEPAYAN
# 7        8  REGKEC/823/19  1901610400008       H KARAN KUMAR
# 8        9       UPSEE-FW  1901610400009      HARIKESH SINGH
# 9       10  REGKEC/411/19  1901610400010    HASSAN CHOUDHARY
# 10      11  REGKEC/853/19  1901610400011      HIMANSHU KUMAR
# 11      12  REGKEC/855/19  1901610400012     HIMANSHU SHARMA
# 12      13  REGKEC/515/19  1901610400013       HIMANSHU VATS
# 13      14  REGKEC/509/19  1901610400014               JATIN
# ...

# %%
df.head()
# Out:
#    S. NO.       REG. NO.       ROLL NO.   STUDENT NAME           Father Name  \
# 0       1  REGKEC/268/19  1901610400001          AMAAN             MR WASEEM
# 1       2  REGKEC/253/19  1901610400002      ANMOL JHA         PRABHAKAR JHA
# 2       3  REGKEC/627/19  1901610400003     ARUN KUMAR         KAILASH VERMA
# 3       4  REGKEC/424/19  1901610400004   ARUNAV KUMAR             TELLU RAM
# 4       5  REGKEC/794/19  1901610400005  ASHOK CHAUHAN  AMAR CHANDRA CHAUHAN
#
#   BRANCH  PCM %   Mobile No     Mobile NO Sec
# 0     ME   74.0  9953981666           NaN  H1
# 1     ME   56.3  9650770855           NaN  G2
# 2     ME   55.7  9540984057           NaN  F2
# 3     ME   56.3  9650291190           NaN  H2
# 4     ME   48.0  9891646301  7.042181e+09  D2

# %%
df.tail()
# Out:
#     S. NO.       REG. NO.       ROLL NO.        STUDENT NAME     Father Name  \
# 24      25  REGKEC/782/19  1901610400025       SANDEEP KUMAR    DINESH KUMAR
# 25      26   REGKEC/37/19  1901610400026   SHANTANU NAUTIYAL  MANOJ NAUTIYAL
# 26      27  REGKEC/347/19  1901610400027         VIKAS VERMA    SANJAY VERMA
# 27      28  REGKEC/711/19  1901610400028         VIKAS YADAV     VIJAY YADAV
# 28      29  REGKEC/725/19  1901610400029  VIKAS KUMAR PASWAN   GANESH PASWAN
#
#    BRANCH  PCM %   Mobile No     Mobile NO Sec
# 24     ME   53.3  9560644171           NaN  F2
# 25     ME   56.0  7838341422           NaN  H2
# 26     ME   49.6  8586997835  7.011601e+08  D2
# 27     ME   49.0  8081590288           NaN  F2
# 28     ME   54.0  8920152129  9.717193e+09  E2

# %%
df.count()
# Out:
# S. NO.          29
# REG. NO.        29
# ROLL NO.        29
# STUDENT NAME    29
# Father Name     29
# BRANCH          29
# PCM %           29
# Mobile No       29
# Mobile NO       15
# Sec             29
# dtype: int64

# %%
df.rank()
# Out:
#     S. NO.  REG. NO.  ROLL NO.  STUDENT NAME  Father Name  BRANCH  PCM %  \
# 0      1.0       5.0       1.0           1.0         20.0    15.0   26.0
# 1      2.0       4.0       2.0           2.0         21.0    15.0   17.5
# 2      3.0      16.0       3.0           3.0         13.0    15.0   14.0
# 3      4.0      10.0       4.0           4.0         27.0    15.0   17.5
# 4      5.0      24.0       5.0           5.0          1.0    15.0    4.0
# 5      6.0       1.0       6.0           6.0          9.0    15.0    7.0
# 6      7.0      19.0       7.0           7.0         11.0    15.0    3.0
# 7      8.0      25.0       8.0           8.0         10.0    15.0   28.0
# 8      9.0      29.0       9.0           9.0         22.0    15.0   20.0
# 9     10.0       8.0      10.0          10.0         16.0    15.0   21.0
# 10    11.0      27.0      11.0          11.0         26.0    15.0   13.0
# 11    12.0      28.0      12.0          12.0          5.0    15.0   24.0
# ...

# %%
df[0:28:25]
# Out:
#     S. NO.       REG. NO.       ROLL NO.       STUDENT NAME     Father Name  \
# 0        1  REGKEC/268/19  1901610400001              AMAAN       MR WASEEM
# 25      26   REGKEC/37/19  1901610400026  SHANTANU NAUTIYAL  MANOJ NAUTIYAL
#
#    BRANCH  PCM %   Mobile No  Mobile NO Sec
# 0      ME   74.0  9953981666        NaN  H1
# 25     ME   56.0  7838341422        NaN  H2

# %%
# Out:
# <bound method NDFrame._is_label_reference of     S. NO.       REG. NO.       ROLL NO.        STUDENT NAME  \
# 0        1  REGKEC/268/19  1901610400001               AMAAN
# 1        2  REGKEC/253/19  1901610400002           ANMOL JHA
# 2        3  REGKEC/627/19  1901610400003          ARUN KUMAR
# 3        4  REGKEC/424/19  1901610400004        ARUNAV KUMAR
# 4        5  REGKEC/794/19  1901610400005       ASHOK CHAUHAN
# 5        6  REGKEC/183/19  1901610400006       DALJEET SINGH
# 6        7  REGKEC/674/19  1901610400007            DEEPAYAN
# 7        8  REGKEC/823/19  1901610400008       H KARAN KUMAR
# 8        9       UPSEE-FW  1901610400009      HARIKESH SINGH
# 9       10  REGKEC/411/19  1901610400010    HASSAN CHOUDHARY
# 10      11  REGKEC/853/19  1901610400011      HIMANSHU KUMAR
# 11      12  REGKEC/855/19  1901610400012     HIMANSHU SHARMA
# 12      13  REGKEC/515/19  1901610400013       HIMANSHU VATS
# 13      14  REGKEC/509/19  1901610400014               JATIN
# ...

# %%
df
# Out:
#     S. NO.       REG. NO.       ROLL NO.        STUDENT NAME  \
# 0        1  REGKEC/268/19  1901610400001               AMAAN
# 1        2  REGKEC/253/19  1901610400002           ANMOL JHA
# 2        3  REGKEC/627/19  1901610400003          ARUN KUMAR
# 3        4  REGKEC/424/19  1901610400004        ARUNAV KUMAR
# 4        5  REGKEC/794/19  1901610400005       ASHOK CHAUHAN
# 5        6  REGKEC/183/19  1901610400006       DALJEET SINGH
# 6        7  REGKEC/674/19  1901610400007            DEEPAYAN
# 7        8  REGKEC/823/19  1901610400008       H KARAN KUMAR
# 8        9       UPSEE-FW  1901610400009      HARIKESH SINGH
# 9       10  REGKEC/411/19  1901610400010    HASSAN CHOUDHARY
# 10      11  REGKEC/853/19  1901610400011      HIMANSHU KUMAR
# 11      12  REGKEC/855/19  1901610400012     HIMANSHU SHARMA
# 12      13  REGKEC/515/19  1901610400013       HIMANSHU VATS
# 13      14  REGKEC/509/19  1901610400014               JATIN
# ...

# %%
df.iloc[[1, 2, 4], [1,2,3]]
# Out:
#         REG. NO.       ROLL NO.   STUDENT NAME
# 1  REGKEC/253/19  1901610400002      ANMOL JHA
# 2  REGKEC/627/19  1901610400003     ARUN KUMAR
# 4  REGKEC/794/19  1901610400005  ASHOK CHAUHAN

# %%
df.iloc[[1],[1]]
# Out:
#         REG. NO.
# 1  REGKEC/253/19

# %%
df.dtypes
# Out:
# S. NO.            int64
# REG. NO.         object
# ROLL NO.          int64
# STUDENT NAME     object
# Father Name      object
# BRANCH           object
# PCM %           float64
# Mobile No         int64
# Mobile NO       float64
# Sec              object
# dtype: object
